# %% [markdown]
# ## 1. Import Relevant Libraries¶

# %%
# !pip install requests
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\chet\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chet\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chet\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chet\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chet\anaconda3\lib\site-packages (from requests) (2025.1.31)
# Requirement already satisfied: beautifulsoup4 in c:\users\chet\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\chet\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)

# %% [markdown]
# ## 2. Perform HTTP Request¶

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/Apple_Inc."
response = requests.get(url)
html_content = response.text

# %% [markdown]
# ## 3. Check the Request Status

# %%
if response.status_code == 200:
    print("Request successful!")
# Out:
# Request successful!

# %% [markdown]
# ## 4. Build the Extraction Model

# %%
soup = BeautifulSoup(html_content, 'html.parser')

# %%
soup = BeautifulSoup(html_content, 'html.parser')

# %% [markdown]
# ## 5. Extract Headings¶

# %%
headings = [heading.text.strip() for heading in soup.find_all(['h1', 'h2', 'h3'])]
print(headings)
# Out:
# ['Contents', 'Apple Inc.', 'History', '1976–1980: Founding and incorporation', '1980–1990: Success with Macintosh', '1990–1997: Decline and restructuring', '1997–2007: Return to profitability', '2007–2011: Success with mobile devices', '2011–present: Post-Jobs era, Tim Cook', 'Products', 'Mac', 'iPhone', 'iPad', 'Other products', 'Services', 'Marketing', 'Branding', 'Advertising', 'Stores', 'Market power', 'Privacy', 'Corporate affairs', 'Business trends', 'Leadership', 'Ownership', 'Corporate culture', 'Offices', 'Litigation', 'Finances', 'Taxes', 'Charity', 'Environment', 'Apple Energy', 'Energy and resources', 'Toxins', 'Green bonds', 'Supply chain', 'Worker organizations', 'Democratic Republic of the Congo', 'See also', 'Notes', 'References', 'Bibliography', 'Further reading', 'External links']

# %% [markdown]
# ## 6. Extract All Paragraphs¶

# %%
paragraphs = [p.text.strip() for p in soup.find_all('p')]
print(paragraphs)
# Out:
# ['', 'Apple Inc. is an American multinational corporation and technology company headquartered in Cupertino, California, in Silicon Valley. It is best known for its consumer electronics, software, and services. Founded in 1976 as Apple Computer Company by Steve Jobs, Steve Wozniak and Ronald Wayne, the company was incorporated by Jobs and Wozniak as Apple Computer, Inc. the following year. It was renamed Apple Inc. in 2007 as the company had expanded its focus from computers to consumer electronics. Apple is the largest technology company by revenue, with US$391.04\xa0billion in the 2024 fiscal year.', 'The company was founded to produce and market Wozniak\'s Apple I personal computer. Its second computer, the Apple II, became a best seller as one of the first mass-produced microcomputers. Apple introduced the Lisa in 1983 and the Macintosh in 1984, as some of the first computers to use a graphical user interface and a mouse. By 1985, internal company problems led to Jobs leaving to form NeXT, Inc., and Wozniak withdrawing to other ventures; John Sculley served as long-time CEO for over a decade. In the 1990s, Apple lost considerable market share in the personal computer industry to the lower-priced Wintel duopoly of the Microsoft Windows operating system on Intel-powered PC clones. In 1997, Apple was weeks away from bankruptcy. To resolve its failed operating system strategy, it bought NeXT, effectively bringing Jobs back to the company, who guided Apple back to profitability over the next decade with the introductions of the iMac, iPod, iPhone, and iPad devices to critical acclaim as well as the iTunes Store, launching the "Think different" advertising campaign, and opening the Apple Store retail chain. These moves elevated Apple to consistently be one of the world\'s most valuable brands since about 2010. Jobs resigned in 2011 for health reasons, and died two months later; he was succeeded as CEO by Tim Cook.', 'Apple\'s product lineup includes portable and home hardware such as the iPhone, iPad, Apple Watch, Mac, and Apple TV; operating systems such as iOS, iPadOS, and macOS; and various software and services including Apple Pay, iCloud, and multimedia streaming services like Apple Music and Apple TV+. Apple is one of the Big Five American information technology companies;[a] for the most part since 2011,[b] Apple has been the world\'s largest company by market capitalization, and, as of 2023[update], is the largest manufacturing company by revenue, the fourth-largest personal computer vendor by unit sales, the largest vendor of tablet computers, and the largest vendor of mobile phones in the world. Apple became the first publicly traded U.S. company to be valued at over $1\xa0trillion in 2018, and, as of December\xa02024[update], is valued at just over $3.74\xa0trillion. Apple is the largest company on the Nasdaq, where it trades under the ticker symbol "AAPL".', "Apple has received criticism regarding its contractors' labor practices, its relationship with trade unions, its environmental practices, and its business ethics, including anti-competitive practices and materials sourcing. Nevertheless, the company has a large following and enjoys a high level of brand loyalty.", 'Apple Computer Company was founded on April 1, 1976, by Steve Jobs, Steve Wozniak, and Ronald Wayne as a partnership.[8][11] The company\'s first product is the Apple I, a computer designed and hand-built entirely by Wozniak.[12] To finance its creation, Jobs sold his Volkswagen Bus, and Wozniak sold his HP-65 calculator.[13]:\u200a57\u200a Neither received the full selling price but in total earned $1,300 (equivalent to $7,200 in 2024). Wozniak debuted the first prototype Apple I at the Homebrew Computer Club in July 1976.[14] The Apple I was sold as a motherboard with CPU, RAM, and basic textual-video chips—a base kit concept which was not yet marketed as a complete personal computer.[15] It was priced soon after debut for $666.66 (equivalent to $3, ...

# %%
paragraphs = [p.text.strip() for p in soup.find_all('p')]
print(paragraphs)
# Out:
# ['', 'Apple Inc. is an American multinational corporation and technology company headquartered in Cupertino, California, in Silicon Valley. It is best known for its consumer electronics, software, and services. Founded in 1976 as Apple Computer Company by Steve Jobs, Steve Wozniak and Ronald Wayne, the company was incorporated by Jobs and Wozniak as Apple Computer, Inc. the following year. It was renamed Apple Inc. in 2007 as the company had expanded its focus from computers to consumer electronics. Apple is the largest technology company by revenue, with US$391.04\xa0billion in the 2024 fiscal year.', 'The company was founded to produce and market Wozniak\'s Apple I personal computer. Its second computer, the Apple II, became a best seller as one of the first mass-produced microcomputers. Apple introduced the Lisa in 1983 and the Macintosh in 1984, as some of the first computers to use a graphical user interface and a mouse. By 1985, internal company problems led to Jobs leaving to form NeXT, Inc., and Wozniak withdrawing to other ventures; John Sculley served as long-time CEO for over a decade. In the 1990s, Apple lost considerable market share in the personal computer industry to the lower-priced Wintel duopoly of the Microsoft Windows operating system on Intel-powered PC clones. In 1997, Apple was weeks away from bankruptcy. To resolve its failed operating system strategy, it bought NeXT, effectively bringing Jobs back to the company, who guided Apple back to profitability over the next decade with the introductions of the iMac, iPod, iPhone, and iPad devices to critical acclaim as well as the iTunes Store, launching the "Think different" advertising campaign, and opening the Apple Store retail chain. These moves elevated Apple to consistently be one of the world\'s most valuable brands since about 2010. Jobs resigned in 2011 for health reasons, and died two months later; he was succeeded as CEO by Tim Cook.', 'Apple\'s product lineup includes portable and home hardware such as the iPhone, iPad, Apple Watch, Mac, and Apple TV; operating systems such as iOS, iPadOS, and macOS; and various software and services including Apple Pay, iCloud, and multimedia streaming services like Apple Music and Apple TV+. Apple is one of the Big Five American information technology companies;[a] for the most part since 2011,[b] Apple has been the world\'s largest company by market capitalization, and, as of 2023[update], is the largest manufacturing company by revenue, the fourth-largest personal computer vendor by unit sales, the largest vendor of tablet computers, and the largest vendor of mobile phones in the world. Apple became the first publicly traded U.S. company to be valued at over $1\xa0trillion in 2018, and, as of December\xa02024[update], is valued at just over $3.74\xa0trillion. Apple is the largest company on the Nasdaq, where it trades under the ticker symbol "AAPL".', "Apple has received criticism regarding its contractors' labor practices, its relationship with trade unions, its environmental practices, and its business ethics, including anti-competitive practices and materials sourcing. Nevertheless, the company has a large following and enjoys a high level of brand loyalty.", 'Apple Computer Company was founded on April 1, 1976, by Steve Jobs, Steve Wozniak, and Ronald Wayne as a partnership.[8][11] The company\'s first product is the Apple I, a computer designed and hand-built entirely by Wozniak.[12] To finance its creation, Jobs sold his Volkswagen Bus, and Wozniak sold his HP-65 calculator.[13]:\u200a57\u200a Neither received the full selling price but in total earned $1,300 (equivalent to $7,200 in 2024). Wozniak debuted the first prototype Apple I at the Homebrew Computer Club in July 1976.[14] The Apple I was sold as a motherboard with CPU, RAM, and basic textual-video chips—a base kit concept which was not yet marketed as a complete personal computer.[15] It was priced soon after debut for $666.66 (equivalent to $3, ...

# %% [markdown]
# ## 7. Extract All Links

# %%
links = [a['href'] for a in soup.find_all('a', href = True)]
print(links)
# Out:
# ['#bodyContent', '/wiki/Main_Page', '/wiki/Wikipedia:Contents', '/wiki/Portal:Current_events', '/wiki/Special:Random', '/wiki/Wikipedia:About', '//en.wikipedia.org/wiki/Wikipedia:Contact_us', '/wiki/Help:Contents', '/wiki/Help:Introduction', '/wiki/Wikipedia:Community_portal', '/wiki/Special:RecentChanges', '/wiki/Wikipedia:File_upload_wizard', '/wiki/Special:SpecialPages', '/wiki/Main_Page', '/wiki/Special:Search', 'https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en', '/w/index.php?title=Special:CreateAccount&returnto=Apple+Inc.', '/w/index.php?title=Special:UserLogin&returnto=Apple+Inc.', 'https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en', '/w/index.php?title=Special:CreateAccount&returnto=Apple+Inc.', '/w/index.php?title=Special:UserLogin&returnto=Apple+Inc.', '/wiki/Help:Introduction', '/wiki/Special:MyContributions', '/wiki/Special:MyTalk', '#', '#History', '#1976–1980:_Founding_and_incorporation', '#1980–1990:_Success_with_Macintosh', '#1990–1997:_Decline_and_restructuring', '#1997–2007:_Return_to_profitability', '#2007–2011:_Success_with_mobile_devices', '#2011–present:_Post-Jobs_era,_Tim_Cook', '#Products', '#Mac', '#iPhone', '#iPad', '#Other_products', '#Services', '#Marketing', '#Branding', '#Advertising', '#Stores', '#Market_power', '#Privacy', '#Corporate_affairs', '#Business_trends', '#Leadership', '#Senior_management', '#Board_of_directors', '#Previous_CEOs', '#Ownership', '#Corporate_culture', '#Offices', '#Litigation', '#Finances', '#Taxes', '#Charity', '#Environment', '#Apple_Energy', '#Energy_and_resources', '#Toxins', '#Green_bonds', '#Supply_chain', '#Worker_organizations', '#Democratic_Republic_of_the_Congo', '#See_also', '#Notes', '#References', '#Bibliography', '#Further_reading', '#External_links', 'https://af.wikipedia.org/wiki/Apple_Inc.', 'https://als.wikipedia.org/wiki/Apple', 'https://am.wikipedia.org/wiki/%E1%8A%A0%E1%8D%95%E1%88%8D_%E1%8A%AE%E1%88%AD%E1%8D%96%E1%88%AC%E1%88%BD%E1%8A%95', 'https://smn.wikipedia.org/wiki/Apple', 'https://ang.wikipedia.org/wiki/Apple_Inc.', 'https://ar.wikipedia.org/wiki/%D8%A3%D8%A8%D9%84', 'https://an.wikipedia.org/wiki/Apple', 'https://hyw.wikipedia.org/wiki/%D4%B7%D6%83%D5%A8%D5%AC', 'https://ast.wikipedia.org/wiki/Apple', 'https://awa.wikipedia.org/wiki/%E0%A4%8F%E0%A4%AA%E0%A5%8D%E0%A4%AA%E0%A4%B2_%E0%A4%87%E0%A4%82%E0%A4%95%E0%A5%B0', 'https://az.wikipedia.org/wiki/Apple', 'https://azb.wikipedia.org/wiki/%D8%A7%D9%BE%D9%84_%D8%B4%DB%8C%D8%B1%DA%A9%D8%AA%DB%8C', 'https://ban.wikipedia.org/wiki/Apple_inc', 'https://bn.wikipedia.org/wiki/%E0%A6%85%E0%A7%8D%E0%A6%AF%E0%A6%BE%E0%A6%AA%E0%A6%B2_%E0%A6%87%E0%A6%A8%E0%A6%95%E0%A6%B0%E0%A7%8D%E0%A6%AA%E0%A7%8B%E0%A6%B0%E0%A7%87%E0%A6%9F%E0%A7%87%E0%A6%A1', 'https://zh-min-nan.wikipedia.org/wiki/Apple_Inc.', 'https://be.wikipedia.org/wiki/Apple', 'https://be-tarask.wikipedia.org/wiki/Apple_Inc.', 'https://bh.wikipedia.org/wiki/%E0%A4%8F%E0%A4%AA%E0%A5%8D%E0%A4%AA%E0%A4%B2_%E0%A4%87%E0%A4%82%E0%A4%95.', 'https://bg.wikipedia.org/wiki/%D0%95%D0%BF%D1%8A%D0%BB', 'https://bs.wikipedia.org/wiki/Apple_Inc.', 'https://br.wikipedia.org/wiki/Apple', 'https://ca.wikipedia.org/wiki/Apple_Inc', 'https://cv.wikipedia.org/wiki/Apple_Inc.', 'https://cs.wikipedia.org/wiki/Apple', 'https://cy.wikipedia.org/wiki/Apple_Inc.', 'https://da.wikipedia.org/wiki/Apple_Inc.', 'https://ary.wikipedia.org/wiki/%D8%A2%D9%BE%D9%84', 'https://se.wikipedia.org/wiki/Apple_Inc.', 'https://de.wikipedia.org/wiki/Apple', 'https://nv.wikipedia.org/wiki/%C3%81k%C3%A1%CA%BC%C3%A1t%CA%BC%C4%AF%C4%AF%C5%82_(b%C3%A9%C3%A9sh_nts%C3%A9kees%C3%ADg%C3%AD%C3%AD_%C3%A1l%CA%BC%C3%ADn%C3%AD)', 'https://dty.wikipedia.org/wiki/%E0%A4%8F%E0%A4%AA%E0%A5%8D%E0%A4%AA%E0%A4%B2_%E0%A4%95%E0%A4%AE%E0%A5%8D%E0%A4%AA%E0%A4%A8%E0%A5%80', 'https://et.wikipedia.org/wiki/Apple_Inc.', 'https://el.wikipedia.org/wiki/Apple', 'https://es.wikipedia.org/wiki/Apple', 'https://e ...

# %% [markdown]
# ## 8. Extract Table

# %%
infobox = soup.find('table', class_ = 'infobox')

if infobox:
    rows = infobox.find_all('tr')
    
    data = {}
    for row in rows:
        header = row.find('th')
        value = row.find('td')
        if header and value:
            data[header.text.strip()] = value.text.strip()
        print(data)
else:
    print("Infobox table not found.")
# Out:
# {}
# {}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)', 'Area served': 'Worldwide'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)', 'Area served': 'Worldwide', 'Key people': 'Tim Cook (CEO)Arthur Levinson (chairman)'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)', 'Area served': 'Worldwide', 'Key people': 'Tim Cook (CEO)Arthur Levinson (chairman)', 'Products': 'AirPods\nApple TV\nApple Watch\niPad\niPhone\nMac'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)', 'Area served': 'Worldwide', 'Key people': 'Tim Cook (CEO)Arthur Levinson (chairman)', 'Products': 'AirPods\nApple TV\nApple Watch\niPad\niPhone\nMac', 'Services': 'App Store\nApple Card\nApple Music\nApple Pay\nApple TV+\niCloud'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)', 'Area served': 'Worldwide', 'Key people': 'Tim Cook (CEO)Arthur Levinson (chairman)', 'Products': 'AirPods\nApple TV\nApple Watch\niPad\niPhone\nMac', 'Services': 'App Store\nApple Card\nApple Music\nApple Pay\nApple TV+\niCloud', 'Revenue': 'US$391 billion\xa0(FY24)'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)', 'Area served': 'Worldwide', 'Key people': 'Tim Cook (CEO)Arthur Levinson (chairman)', 'Products': 'AirPods\nApple TV\nApple Watch\niPad\niPhone\nMac', 'Services': 'App Store\nApple Card\nApple Music\nApple Pay\nApple TV+\niCloud', 'Revenue': 'US$391 billion\xa0(FY24)', 'Operating income': 'US$123 billion\xa0(FY24)'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)', 'Area served': 'Worldwide', 'Key people': 'Tim Cook (CEO)Arthur Levinson (chairman)', 'Products': 'AirPods\nApple TV\nApple Watch\niPad\niPhone\nMac', 'Services': 'App Store\nApple Card\nApple Music\nApple Pay\nApple TV+\niCloud', 'Revenue': 'US$391 billion\xa0(FY24)', 'Operating income': 'US$123 billion\xa0(FY24)', 'Net income': 'US$94 billion\xa0(FY24)'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)', 'Area served': 'Worldwide', 'Key people': 'Tim Cook (CEO)Arthur Levinson (chairman)', 'Products': 'AirPods\nApple TV\nApple Watch\niPad\niPhone\nMac', 'Services': 'App Store\nApple Card\nApple Music\nApple Pay\nApple TV+\niCloud', 'Revenue': 'US$391 billion\xa0(FY24)', 'Operating income': 'US$123 billion\xa0(FY24)', 'Net income': 'US$94 billion\xa0(FY24)', 'Total assets': 'US$365 billion\xa0(FY24)'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)', 'Area served': 'Worldwide', 'Key people': 'Tim Cook (CEO)Arthur Levinson (chairman)', 'Products': 'AirPods\nApple TV\nApple Watch\niPad\niPhone\nMac', 'Services': 'App Store\nApple Card\nApple Music\nApple Pay\nApple TV+\niCloud', 'Revenue': 'US$391 billion\xa0(FY24)', 'Operating income': 'US$123 billion\xa0(FY24)', 'Net income': 'US$94 billion\xa0(FY24)', 'Total assets': 'US$365 billion\xa0(FY24)', 'Total equity': 'US$57 billion\xa0(FY24)'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)', 'Area served': 'Worldwide', 'Key people': 'Tim Cook (CEO)Arthur Levinson (chairman)', 'Products': 'AirPods\nApple TV\nApple Watch\niPad\niPhone\nMac', 'Services': 'App Store\nApple Card\nApple Music\nApple Pay\nApple TV+\niCloud', 'Revenue': 'US$391 billion\xa0(FY24)', 'Operating income': 'US$123 billion\xa0(FY24)', 'Net income': 'US$94 billion\xa0(FY24)', 'Total assets': 'US$365 billion\xa0(FY24)', 'Total equity': 'US$57 billion\xa0(FY24)', 'Number of employees': '164,000\xa0(FY24)'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)', 'Area served': 'Worldwide', 'Key people': 'Tim Cook (CEO)Arthur Levinson (chairman)', 'Products': 'AirPods\nApple TV\nApple Watch\niPad\niPhone\nMac', 'Services': 'App Store\nApple Card\nApple Music\nApple Pay\nApple TV+\niCloud', 'Revenue': 'US$391 billion\xa0(FY24)', 'Operating income': 'US$123 billion\xa0(FY24)', 'Net income': 'US$94 billion\xa0(FY24)', 'Total assets': 'US$365 billion\xa0(FY24)', 'Total equity': 'US$57 billion\xa0(FY24)', 'Number of employees': '164,000\xa0(FY24)', 'Subsidiaries': 'Apple StudiosBeats ElectronicsBedditBraeburn CapitalClarisGlobalstar (20%)'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)', 'Area served': 'Worldwide', 'Key people': 'Tim Cook (CEO)Arthur Levinson (chairman)', 'Products': 'AirPods\nApple TV\nApple Watch\niPad\niPhone\nMac', 'Services': 'App Store\nApple Card\nApple Music\nApple Pay\nApple TV+\niCloud', 'Revenue': 'US$391 billion\xa0(FY24)', 'Operating income': 'US$123 billion\xa0(FY24)', 'Net income': 'US$94 billion\xa0(FY24)', 'Total assets': 'US$365 billion\xa0(FY24)', 'Total equity': 'US$57 billion\xa0(FY24)', 'Number of employees': '164,000\xa0(FY24)', 'Subsidiaries': 'Apple StudiosBeats ElectronicsBedditBraeburn CapitalClarisGlobalstar (20%)'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)', 'Area served': 'Worldwide', 'Key people': 'Tim Cook (CEO)Arthur Levinson (chairman)', 'Products': 'AirPods\nApple TV\nApple Watch\niPad\niPhone\nMac', 'Services': 'App Store\nApple Card\nApple Music\nApple Pay\nApple TV+\niCloud', 'Revenue': 'US$391 billion\xa0(FY24)', 'Operating income': 'US$123 billion\xa0(FY24)', 'Net income': 'US$94 billion\xa0(FY24)', 'Total assets': 'US$365 billion\xa0(FY24)', 'Total equity': 'US$57 billion\xa0(FY24)', 'Number of employees': '164,000\xa0(FY24)', 'Subsidiaries': 'Apple StudiosBeats ElectronicsBedditBraeburn CapitalClarisGlobalstar (20%)', 'ASN': '714'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)', 'Area served': 'Worldwide', 'Key people': 'Tim Cook (CEO)Arthur Levinson (chairman)', 'Products': 'AirPods\nApple TV\nApple Watch\niPad\niPhone\nMac', 'Services': 'App Store\nApple Card\nApple Music\nApple Pay\nApple TV+\niCloud', 'Revenue': 'US$391 billion\xa0(FY24)', 'Operating income': 'US$123 billion\xa0(FY24)', 'Net income': 'US$94 billion\xa0(FY24)', 'Total assets': 'US$365 billion\xa0(FY24)', 'Total equity': 'US$57 billion\xa0(FY24)', 'Number of employees': '164,000\xa0(FY24)', 'Subsidiaries': 'Apple StudiosBeats ElectronicsBedditBraeburn CapitalClarisGlobalstar (20%)', 'ASN': '714'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)', 'Area served': 'Worldwide', 'Key people': 'Tim Cook (CEO)Arthur Levinson (chairman)', 'Products': 'AirPods\nApple TV\nApple Watch\niPad\niPhone\nMac', 'Services': 'App Store\nApple Card\nApple Music\nApple Pay\nApple TV+\niCloud', 'Revenue': 'US$391 billion\xa0(FY24)', 'Operating income': 'US$123 billion\xa0(FY24)', 'Net income': 'US$94 billion\xa0(FY24)', 'Total assets': 'US$365 billion\xa0(FY24)', 'Total equity': 'US$57 billion\xa0(FY24)', 'Number of employees': '164,000\xa0(FY24)', 'Subsidiaries': 'Apple StudiosBeats ElectronicsBedditBraeburn CapitalClarisGlobalstar (20%)', 'ASN': '714', 'Website': 'apple.com'}
# {'Formerly': 'Apple Computer Company (1976–1977)Apple Computer, Inc. (1977–2007)', 'Company type': 'Public', 'Traded as': 'Nasdaq:\xa0AAPLNasdaq-100 componentDJIA componentS&P 100 componentS&P 500 component', 'ISIN': 'US0378331005', 'Industry': 'Consumer electronicsSoftware servicesOnline services', 'Founded': 'April\xa01, 1976; 49 years ago\xa0(1976-04-01), in Los Altos, California, U.S.', 'Founders': 'Steve JobsSteve WozniakRonald Wayne', 'Headquarters': '1 Apple Park Way, Cupertino, California, U.S.', 'Number of locations': '535 Apple Stores\xa0(2025)', 'Area served': 'Worldwide', 'Key people': 'Tim Cook (CEO)Arthur Levinson (chairman)', 'Products': 'AirPods\nApple TV\nApple Watch\niPad\niPhone\nMac', 'Services': 'App Store\nApple Card\nApple Music\nApple Pay\nApple TV+\niCloud', 'Revenue': 'US$391 billion\xa0(FY24)', 'Operating income': 'US$123 billion\xa0(FY24)', 'Net income': 'US$94 billion\xa0(FY24)', 'Total assets': 'US$365 billion\xa0(FY24)', 'Total equity': 'US$57 billion\xa0(FY24)', 'Number of employees': '164,000\xa0(FY24)', 'Subsidiaries': 'Apple StudiosBeats ElectronicsBedditBraeburn CapitalClarisGlobalstar (20%)', 'ASN': '714', 'Website': 'apple.com'}

# %% [markdown]
# ## 9. Convert Table into a DataFrame¶

# %%
table = pd.DataFrame(list(data.items()), columns = ['Key', 'Value'])
table
# Out:
#                     Key                                              Value
# 0              Formerly  Apple Computer Company (1976–1977)Apple Comput...
# 1          Company type                                             Public
# 2             Traded as  Nasdaq: AAPLNasdaq-100 componentDJIA component...
# 3                  ISIN                                       US0378331005
# 4              Industry  Consumer electronicsSoftware servicesOnline se...
# 5               Founded  April 1, 1976; 49 years ago (1976-04-01), in L...
# 6              Founders                Steve JobsSteve WozniakRonald Wayne
# 7          Headquarters      1 Apple Park Way, Cupertino, California, U.S.
# 8   Number of locations                            535 Apple Stores (2025)
# 9           Area served                                          Worldwide
# 10           Key people           Tim Cook (CEO)Arthur Levinson (chairman)
# 11             Products  AirPods\nApple TV\nApple Watch\niPad\niPhone\nMac
# 12             Services  App Store\nApple Card\nApple Music\nApple Pay\...
# 13              Revenue                              US$391 billion (FY24)
# 14     Operating income                              US$123 billion (FY24)
# 15           Net income                               US$94 billion (FY24)
# 16         Total assets                              US$365 billion (FY24)
# 17         Total equity                               US$57 billion (FY24)
# 18  Number of employees                                     164,000 (FY24)
# 19         Subsidiaries  Apple StudiosBeats ElectronicsBedditBraeburn C...
# 20                  ASN                                                714
# 21              Website                                          apple.com

# %% [markdown]
# ## 10. Export the Table¶

# %%
table.to_excel("apple_inc_summary_table.xlsx")
