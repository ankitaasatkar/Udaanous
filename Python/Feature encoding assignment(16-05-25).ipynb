# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/Chet/Documents/practice_data2.csv")

# %%
data.head()
# Out:
#    EmployeeID  gender       department  Days Present Accuracy_of_Work  \
# 0           1    Male            Sales            20             High
# 1           2  Female        Marketing            22           Medium
# 2           3    Male  Human Resources            25             High
# 3           4    Male      Engineering            19              Low
# 4           5  Female          Finance            23           Medium
#
#   Meeting Project Deadlines  Task Completion Rates  \
# 0                       Yes                     85
# 1                       Yes                     90
# 2                        No                     80
# 3                       Yes                     75
# 4                       Yes                     85
#
#    Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                            8                              7
# 1                            7                              6
# ...

# %% [markdown]
# ##  The first value of the gender column after performing the label encoding?

# %%
encoder = LabelEncoder()
data['gender'] = encoder.fit_transform(data['gender'])
data.head()
# Out:
#    EmployeeID  gender       department  Days Present Accuracy_of_Work  \
# 0           1       1            Sales            20             High
# 1           2       0        Marketing            22           Medium
# 2           3       1  Human Resources            25             High
# 3           4       1      Engineering            19              Low
# 4           5       0          Finance            23           Medium
#
#   Meeting Project Deadlines  Task Completion Rates  \
# 0                       Yes                     85
# 1                       Yes                     90
# 2                        No                     80
# 3                       Yes                     75
# 4                       Yes                     85
#
#    Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                            8                              7
# 1                            7                              6
# ...

# %% [markdown]
# ## selecting Feature

# %%
import pandas as pd

# %%
data2 = pd.read_csv("C:/Users/Chet/Documents/practice_data2.csv")

# %%
data2.head()
# Out:
#    EmployeeID  gender       department  Days Present Accuracy_of_Work  \
# 0           1    Male            Sales            20             High
# 1           2  Female        Marketing            22           Medium
# 2           3    Male  Human Resources            25             High
# 3           4    Male      Engineering            19              Low
# 4           5  Female          Finance            23           Medium
#
#   Meeting Project Deadlines  Task Completion Rates  \
# 0                       Yes                     85
# 1                       Yes                     90
# 2                        No                     80
# 3                       Yes                     75
# 4                       Yes                     85
#
#    Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                            8                              7
# 1                            7                              6
# ...

# %%
x = data2.drop(['EmployeeID'], axis=1)
x.head()
# Out:
#    gender       department  Days Present Accuracy_of_Work  \
# 0    Male            Sales            20             High
# 1  Female        Marketing            22           Medium
# 2    Male  Human Resources            25             High
# 3    Male      Engineering            19              Low
# 4  Female          Finance            23           Medium
#
#   Meeting Project Deadlines  Task Completion Rates  \
# 0                       Yes                     85
# 1                       Yes                     90
# 2                        No                     80
# 3                       Yes                     75
# 4                       Yes                     85
#
#    Interpersonal Skills Rating  Decision-Making Skills Rating  \
# 0                            8                              7
# 1                            7                              6
# 2                            9                              8
# ...

# %% [markdown]
# ##  StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
features = ['Days Present', 'Task Completion Rates', 'Interpersonal Skills Rating',
    'Decision-Making Skills Rating', 'Sales Revenue Generated']

scaler = StandardScaler()
scaled = scaler.fit_transform(data[features])
scaled_features = pd.DataFrame(scaled, columns=features)
scaled_features
# Out:
#     Days Present  Task Completion Rates  Interpersonal Skills Rating  \
# 0      -0.588120               0.854965                     0.857075
# 1       0.301232               1.407129                     0.026784
# 2       1.635260               0.302800                     1.687365
# 3      -1.032796              -0.249365                    -0.803507
# 4       0.745908               0.854965                     0.026784
# 5      -0.143444               1.959294                     0.857075
# 6       1.190584              -0.801529                    -1.633798
# 7      -1.477471               0.302800                    -0.803507
# 8      -0.588120               1.407129                     0.857075
# 9       0.301232               0.854965                     0.026784
# 10      1.635260              -0.249365                     1.687365
# 11     -1.032796              -0.801529                    -0.803507
# 12      0.745908               0.302800                     0.026784
# ...

# %% [markdown]
# ##  MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaled = scaler.fit_transform(data[numeric_cols])
scaled_features = pd.DataFrame(scaled, columns=numeric_cols)

scaled_features
# Out:
#     Days Present  Task Completion Rates  Interpersonal Skills Rating  \
# 0       0.285714               0.714286                         0.75
# 1       0.571429               0.857143                         0.50
# 2       1.000000               0.571429                         1.00
# 3       0.142857               0.428571                         0.25
# 4       0.714286               0.714286                         0.50
# 5       0.428571               1.000000                         0.75
# 6       0.857143               0.285714                         0.00
# 7       0.000000               0.571429                         0.25
# 8       0.285714               0.857143                         0.75
# 9       0.571429               0.714286                         0.50
# 10      1.000000               0.428571                         1.00
# 11      0.142857               0.285714                         0.25
# 12      0.714286               0.571429                         0.50
# ...

# %% [markdown]
# ## PCA

# %%
numeric_col = [ 'Days Present', 'Task Completion Rates','Interpersonal Skills Rating', 'Decision-Making Skills Rating', 'Sales Revenue Generated']
features = data[numeric_cols]

scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

pca = PCA()
temp_pca = pca.fit_transform(scaled_features)

evr = pca.explained_variance_ratio_
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(evr) + 1), evr, marker='o')
plt.title('Explained Variance Ratio by Number of Components')
plt.xlabel('Number of Components')
plt.ylabel('Explained Variance Ratio')
plt.grid(True)
plt.show()


num_components = 3
pca = PCA(n_components=num_components)
x_pca = pca.fit_transform(scaled_features)

print(f"PCA result shape: {x_pca.shape}")
print("First few rows of PCA-transformed data:")
print(pd.DataFrame(x_pca, columns=[f'PC{i+1}' for i in range(num_components)]))
# Out:
# PCA result shape: (31, 3)
# First few rows of PCA-transformed data:
#          PC1       PC2       PC3
# 0   1.153925 -0.634436 -1.621233
# 1   0.684950  1.293587  1.308712
# 2   2.071453 -0.416042  2.024427
# 3  -1.239082  1.609569  0.187667
# 4   0.774734 -0.805317 -0.077870
# 5   2.340555  1.109791  0.445344
# 6  -2.422062 -0.798288  0.830598
# 7  -0.497426  2.210576  0.006021
# 8   1.515331  0.581818 -0.537600
# 9   0.359370  0.628742  0.798870
# 10  1.725312 -1.397340  1.185286
# 11 -1.515500  1.701397  0.465212
# 12  0.492508 -0.802889  0.106646
# 13  2.058195  1.110161  0.627719
# 14 -2.695920 -0.667044  1.149159
# 15 -0.823168  1.543253 -0.506400
# 16  1.224504  0.451876 -0.490826
# 17 -0.005630 -0.642826 -0.342322
# 18  1.357724 -2.708745  0.002639
# 19 -1.855185  0.819458 -0.270537
# 20  0.232364 -0.460583  0.644837
# 21  1.657266 -0.714404 -1.088918
# 22 -3.032129 -1.495492  0.469072
# 23 -1.216705 -0.167552 -2.104660
# 24  0.934503  0.334652 -0.430819
# ...

# %% [markdown]
# ## Train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
features = ['Days Present', 'Task Completion Rates', 'Interpersonal Skills Rating',
           'Decision-Making Skills Rating', 'Sales Revenue Generated','gender', 'department', 'Accuracy_of_Work', 'Meeting Project Deadlines']



x_train, x_test, y_train, y_test = train_test_split(scaled, y, test_size=0.2, random_state=42)

print("Training set shape:", x_train.shape)
print("Test set shape:", x_test.shape)
# Out:
# Training set shape: (24, 5)
# Test set shape: (7, 5)
